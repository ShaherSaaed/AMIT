# %% [markdown]
# ## Tasks
# * Analyze and Explain [Covid dataset](https://www.kaggle.com/datasets/imdevskp/corona-virus-report)
# * Search for:
#     * Line chart
#     * Area chart
#     * Waffle chart
#     * Regression plots

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.options.display.float_format = '{: .2f}'.format

# %%
df = pd.read_csv('Datasets\\country_wise_latest.csv')
df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187 entries, 0 to 186
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country/Region          187 non-null    object
#  1   Confirmed               187 non-null    int64
#  2   Deaths                  187 non-null    int64
#  3   Recovered               187 non-null    int64
#  4   Active                  187 non-null    int64
#  5   New cases               187 non-null    int64
#  6   New deaths              187 non-null    int64
#  7   New recovered           187 non-null    int64
#  8   Deaths / 100 Cases      187 non-null    float64
#  9   Recovered / 100 Cases   187 non-null    float64
#  10  Deaths / 100 Recovered  187 non-null    float64
#  11  Confirmed last week     187 non-null    int64
#  12  1 week change           187 non-null    int64
#  13  1 week % increase       187 non-null    float64
# ...

# %%
df.describe().T
# Out:
# d:\Shaher\AMIT\.venv\Lib\site-packages\pandas\core\nanops.py:1016: RuntimeWarning: invalid value encountered in subtract
#   sqr = _ensure_numeric((avg - values) ** 2)
#                          count      mean        std    min      25%      50%  \
# Confirmed               187.00  88130.94  383318.66  10.00  1114.00  5059.00
# Deaths                  187.00   3497.52   14100.00   0.00    18.50   108.00
# Recovered               187.00  50631.48  190188.19   0.00   626.50  2815.00
# Active                  187.00  34001.94  213326.17   0.00   141.50  1600.00
# New cases               187.00   1222.96    5710.37   0.00     4.00    49.00
# New deaths              187.00     28.96     120.04   0.00     0.00     1.00
# New recovered           187.00    933.81    4197.72   0.00     0.00    22.00
# Deaths / 100 Cases      187.00      3.02       3.45   0.00     0.94     2.15
# Recovered / 100 Cases   187.00     64.82      26.29   0.00    48.77    71.32
# ...

# %%
df.groupby(df['Confirmed'])[['Deaths', 'Recovered', 'Active']].sum()
# Out:
#            Deaths  Recovered   Active
# Confirmed
# 10              1          8        1
# 12              0         12        0
# 14              0         13        1
# 17              0         15        2
# 18              0         18        0
# ...           ...        ...      ...
# 452529       7067     274925   170537
# 816680      13334     602249   201097
# 1480073     33408     951166   495499
# 2442375     87618    1846641   508116
# 4290259    148011    1325804  2816444
#
# [184 rows x 3 columns]

# %%
df[df['Deaths / 100 Recovered'] > 80]
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 32           Canada     116458    8944          0  107514        682
# 117      Mozambique       1701      11          0    1690         32
# 120     Netherlands      53413    6160        189   47064        419
# 147          Serbia      24141     543          0   23598        411
# 161          Sweden      79395    5700          0   73695        398
# 163           Syria        674      40          0     634         24
# 177  United Kingdom     301708   45844       1437  254427        688
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 32           11              0                7.68                   0.00
# 117           0              0                0.65                   0.00
# 120           1              0               11.53                   0.35
# 147           9              0                2.25                   0.00
# ...

# %%
df[df['Confirmed'] > 2000000]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  New cases  \
# 23          Brazil    2442375   87618    1846641   508116      23284
# 173             US    4290259  148011    1325804  2816444      56336
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 23          614          33728                3.59                  75.61
# 173        1076          27941                3.45                  30.90
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 23                     4.74              2118646         323729
# 173                   11.16              3834677         455582
#
#      1 week % increase WHO Region
# 23               15.28   Americas
# 173              11.88   Americas
