# %% [markdown]
# # **Congressional Voting Records**
#
# > This dataset contains voting records of members of the U.S. House of Representatives during the 98th Congress in 1984. The data represents how each congressman voted on 16 different issues that were debated and voted on in Congress. The goal of this dataset is to predict the political party affiliation of a congressman (whether they are a Democrat or Republican) based on their voting behavior.

# %% [markdown]
# ## **Key Points about the Data**
#
# 1. Number of Entries (Rows)
#     * The dataset contains 435 rows, each representing a single congressman or congresswoman.
#
# 2. Attributes (Columns)
#     * **Party**: The target label indicating whether the congressman is from the **Democratic** Party or the **Republican** Party.
#
#     * **Voting on Issues**: There are 16 columns representing key political issues that were voted on. Each column indicates how the congressman voted on that issue:
#          * **y**: Yes vote
#          * **n**: No vote
#          * **?**: Abstained or unknown (missing vote)
#
#
# Some of the issues that were voted on include topics like:
#   * **Handicapped infants**: Whether to provide assistance to handicapped infants.
#   * **Water project cost-sharing**: Whether the government should fund water projects.
#   * **Defense spending**: How much money should be allocated to defense.
#   * **Education spending**: How much the government should spend on education.
#   * **Foreign aid**: Whether to provide financial assistance to other countries.

# %% [markdown]
# ## **What Does the Data Represent?**
# > The data reflects how each congressman voted on 16 critical political issues. By looking at how they voted (yes, no, or abstained), it’s possible to predict whether they are a Democrat or a Republican.
#
# **For example**, if a congressman consistently voted yes on issues related to education spending or social welfare, they might be classified as a Democrat. If they voted no on these issues but supported military spending, they might lean more toward the Republican side.
#
# The Party column (the target variable) tells us whether a congressman belongs to the Democratic Party or the Republican Party based on their voting pattern.

# %% [markdown]
# # **Project Tasks** 📔

# %% [markdown]
# **1. Data Exploration**
#   * Understand the structure and content of the dataset.
#     * **steps**:
#        1. **Load the dataset** (house-votes-84.csv) into a pandas DataFrame.
#        2. **Display the first** few rows using .head() to examine the columns and data types.
#        3. **Use** .info() and .describe() to get an overview of the dataset.
#        4. **Check for missing values** using .isnull().sum().
#
# **2. Data Cleaning**
#    * Address issues in the dataset such as missing values, inconsistencies, and duplicates
#      * **Steps**:
#         1. Handle missing values:
#            * Replace missing values with the most frequent category or use other imputation techniques.
#         2. Correct inconsistencies:
#            * Clean the Party column by mapping inconsistent labels (e.g., "repub" -> "republican").
#         3. Remove duplicate rows using .drop_duplicates().
#         4. Handle outliers in numeric columns like Handicapped-infants and Crime.
#
# **3. Data Visualization**
#    * Analyze the data distribution and identify trends or patterns.
#       * **Steps**:
#          1. **Plot the distribution** of categorical columns such as Party and voting patterns using bar charts.
#          2. **Use histograms or boxplots** to analyze numeric columns.
#          3. **Visualize correlations** between features (e.g., voting patterns and political affiliation).
#
# **4. Feature Engineering**
#    * Prepare the dataset for predictive modeling.
#       * **Steps**:
#          1. **Convert** categorical columns (votes) into numeric format (e.g., y=1, n=0, ?=NaN or Unknown).
#          2. **Standardize or normalize** numeric columns if necessary.
#          3. **Create additional features** if you identify relationships in the data.
#
#
# **5. Train-Test Split**
#   * Prepare the dataset for machine learning.
#      * **Steps**:
#        1. **Split the dataset** into training and testing sets using an 80/20 ratio.
#        2. **Use stratified** splitting to ensure balanced class representation.
#
# **6. Model Building**
#   * Predict the Party column based on voting patterns
#      * **Steps**:
#         1. **Train** multiple classification models:
#           * Logistic Regression
#           * Random Forest
#           * Support Vector Machine (SVM)
#           * XGBoost
#
#        2. **Tune hyperparameters** for each model to improve accuracy.
#
#
# **7. Model Evaluation**
#   * Evaluate and compare model performance.
#      * **Steps**:
#        1. **Calculate** accuracy, precision, recall, and F1-score for each model.
#        2. Use cross-validation to validate your results.
#        3. Identify the best-performing model and analyze its predictions.
#
#
# **8. Improving Accuracy (Challenge)**
#   * Push the boundaries to achieve higher accuracy than the benchmarks.
#     * **Steps**:
#       1. Use advanced techniques such as ensemble methods (stacking, boosting).
#       2. Perform feature selection to identify the most important votes.
#       3. Experiment with data augmentation to address class imbalance.
#
# **9. Insights and Report**
#    * Summarize the findings and insights from your analysis.
#      * **Steps**:
#        1. **Discuss** the most influential voting patterns for predicting political affiliation.
#        2. **Explain** how the challenges in the dataset were addressed.
#        3. **Compare** the performance of different models and justify your approach.

# %% [markdown]
# ### **Goal**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# > Your objective is to achieve a higher accuracy than the benchmarks provided (e.g., Logistic Regression: ~90%). Use creativity and advanced techniques to improve your results!

# %% [markdown]
# # **Submit and Showcase Your Project**
