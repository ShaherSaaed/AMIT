# %% [markdown]
# ## Notes
# * Feature Selection
#   * Filter Method
#     * Statistical Methods
#   * Embedded Method
#     * Embedded in the algorithm
#     * Lasso
#   * Wrapper Method
#     * Forward elemination
#     * Backward elemination
# * Dimension Reduction
#   * PCA
#     * Measures the variance of each column, and compares it with the others, then drops if the variance is less than a threshold
#   * t-SNE
# * For enoding, no difference if before and after splitting
# * If has fit and transform, do it after splitting to avoid data leakage
# * If test accuracy > train accuracy
#   * Test data is small
#   * Test data is not covering all cases
#   * Data Leakage
# * elqa3da el 3amma bt2ol b3d el rain_test_split
# * PCA doesn't affect tree models
#
# ## To ask
# * What is the difference between validation, and CVs
#
# ## To Search For
# * Catboost
# * DM-Crisp
# * Anamoly Detection
# * Binary Encoding
# * Cyclic Encoding
# * or hyperparameter tuning
#   * optuna
#   * keras tuner
#
# ## Project Workflow
# 1. Understand the Business
#   * Define Problem
#     * Success Criteria
#   * RoI (Return of Investment)
#     * Why they work?
#     * What in return?
#   * Tehchnical Requirment
#     * Collct & Understand Data
#   * PoC (Proof of Concept)
# 2. Data Preprocessing & Exploration (EDA)
#     1. Check missing
#     2. Check Duplicates
#     3. Check Outliers
#       * Mean: if data is normally Distributed
#       * Median: if data has alot of outliers
#       * Clipping: if a lot of values are outliers
#     4. Encode Data
#       * Binary Encoder
#     5. Normalization/Scaling
#       * Normalization -> between 0-1
#       * Scaling
# 3. Explore Data (Can be before encoding)
#   * Check Data imbalance
# 4. Feature Engineering
#   * Create new feature and remove non related (e.g. length, width, convert into area)
#   * Transform Features (Age from 1 to 100, convert into categories)
#   * Log (if data is skewed)
#   * Extract feature
# 5. Feature Selection
# 6. Modeling & Hyperparameter selection
#   * train_test_split
#   * Choose which model to work with
#   * Train Model (to compare with other model)
#   * Cross validation
#   * Hyperparameter Tuning
# 7. Deployment

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split, GridSearchSplitCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVCfrom sklearn
