# %%
import re
import nltk

# %%
from numpy import random
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import twitter_samples, stopwords
from tensorflow.keras.preprocessing.text import Tokenizer
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import word_tokenize
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, SimpleRNN, Dense, Dropout, Embedding

# %%
nltk.download('twitter_samples')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package twitter_samples to /root/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
pos_tweets = twitter_samples.strings("positive_tweets.json")
neg_tweets = twitter_samples.strings("negative_tweets.json")
tweets = pos_tweets + neg_tweets

# %%
pos_tweets

# %%
neg_tweets[2]
# Out:
# '@Hegelbon That heart sliding into the waste basket. :('

# %%
print("pos_tweets length:", len(pos_tweets))
print("neg_tweets length:", len(neg_tweets))
print("total_tweets length:", len(tweets))
# Out:
# pos_tweets length: 5000
# neg_tweets length: 5000
# total_tweets length: 10000

# %%
stop_words = set(stopwords.words('english'))
tokenizer = CountVectorizer()
lemmatizer = WordNetLemmatizer()

# %%
def preprocess(tweet):
  tweet = re.sub(r'[^A-Za-z0-9\s]|http.*\s?|\s[0-9]\s|\?{2,}|!{2,}', ' ', tweet)

  tweet = tweet.lower()

  tweet = word_tokenize(tweet)

  tweet = [lemmatizer.lemmatize(word) for word in tweet if word not in stop_words]

  return tweet

# %%
for i in range(3):
  display(tweets[i])
# Out:
# '#FollowFriday @France_Inte @PKuchly57 @Milipol_Paris for being top engaged members in my community this week :)'
# '@Lamb2ja Hey James! How odd :/ Please call our Contact Centre on 02392441234 and we will be able to assist you :) Many thanks!'
# '@DespiteOfficial we had a listen last night :) As You Bleed is an amazing track. When are you in Scotland?!'

# %%
preprocessed_tweets = [' '.join(preprocess(tweets[i])) for i in range(3)]

# %%
preprocessed_tweets
# Out:
# ['followfriday france inte pkuchly57 milipol paris top engaged member community week',
#  'lamb2ja hey james odd please call contact centre 02392441234 able assist many thanks',
#  'despiteofficial listen last night bleed amazing track scotland']

# %%
pos_tweets[5]
# Out:
# '@BhaktisBanter @PallaviRuhail This one is irresistible :)\n#FlipkartFashionFriday http://t.co/EbZ0L2VENM'

# %%
preprocess(pos_tweets[5])
# Out:
# ['bhaktisbanter',
#  'pallaviruhail',
#  'one',
#  'irresistible',
#  'flipkartfashionfriday',
#  'http',
#  'co',
#  'ebz',
#  'l',
#  'venm']

# %%
text = "This is a text"
tokens = word_tokenize(text.lower())

# %%
tokens
# Out:
# ['this', 'is', 'a', 'text']
