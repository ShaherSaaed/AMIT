# %%
import pandas as pd

# %%
df = pd.read_csv("Datasets\\OnlineNewsPopularity\\OnlineNewsPopularity.csv")

# %%
df.head()
# Out:
#                                                  url   timedelta  \
# 0  http://mashable.com/2013/01/07/amazon-instant-...       731.0
# 1  http://mashable.com/2013/01/07/ap-samsung-spon...       731.0
# 2  http://mashable.com/2013/01/07/apple-40-billio...       731.0
# 3  http://mashable.com/2013/01/07/astronaut-notre...       731.0
# 4   http://mashable.com/2013/01/07/att-u-verse-apps/       731.0
#
#     n_tokens_title   n_tokens_content   n_unique_tokens   n_non_stop_words  \
# 0             12.0              219.0          0.663594                1.0
# 1              9.0              255.0          0.604743                1.0
# 2              9.0              211.0          0.575130                1.0
# 3              9.0              531.0          0.503788                1.0
# 4             13.0             1072.0          0.415646                1.0
#
#     n_non_stop_unique_tokens   num_hrefs   num_self_hrefs   num_imgs  ...  \
# 0                   0.815385         4.0              2.0        1.0  ...
# 1                   0.791946         3.0              1.0        1.0  ...
# 2                   0.663866         3.0              1.0        1.0  ...
# 3                   0.665635         9.0              0.0        1.0  ...
# 4                   0.540890        19.0             19.0       20.0  ...
#
#     min_positive_polarity   max_positive_polarity   avg_negative_polarity  \
# 0                0.100000                     0.7               -0.350000
# 1                0.033333                     0.7               -0.118750
# 2                0.100000                     1.0               -0.466667
# 3                0.136364                     0.8               -0.369697
# 4                0.033333                     1.0               -0.220192
#
#     min_negative_polarity   max_negative_polarity   title_subjectivity  \
# 0                  -0.600               -0.200000             0.500000
# 1                  -0.125               -0.100000             0.000000
# 2                  -0.800               -0.133333             0.000000
# 3                  -0.600               -0.166667             0.000000
# 4                  -0.500               -0.050000             0.454545
#
#     title_sentiment_polarity   abs_title_subjectivity  \
# 0                  -0.187500                 0.000000
# 1                   0.000000                 0.500000
# 2                   0.000000                 0.500000
# 3                   0.000000                 0.500000
# 4                   0.136364                 0.045455
#
#     abs_title_sentiment_polarity   shares
# 0                       0.187500      593
# 1                       0.000000      711
# 2                       0.000000     1500
# 3                       0.000000     1200
# 4                       0.136364      505
#
# [5 rows x 61 columns]

# %%
df.shape
# Out:
# (39644, 61)

# %%
df.columns
# Out:
# Index(['url', ' timedelta', ' n_tokens_title', ' n_tokens_content',
#        ' n_unique_tokens', ' n_non_stop_words', ' n_non_stop_unique_tokens',
#        ' num_hrefs', ' num_self_hrefs', ' num_imgs', ' num_videos',
#        ' average_token_length', ' num_keywords', ' data_channel_is_lifestyle',
#        ' data_channel_is_entertainment', ' data_channel_is_bus',
#        ' data_channel_is_socmed', ' data_channel_is_tech',
#        ' data_channel_is_world', ' kw_min_min', ' kw_max_min', ' kw_avg_min',
#        ' kw_min_max', ' kw_max_max', ' kw_avg_max', ' kw_min_avg',
#        ' kw_max_avg', ' kw_avg_avg', ' self_reference_min_shares',
#        ' self_reference_max_shares', ' self_reference_avg_sharess',
#        ' weekday_is_monday', ' weekday_is_tuesday', ' weekday_is_wednesday',
#        ' weekday_is_thursday', ' weekday_is_friday', ' weekday_is_saturday',
#        ' weekday_is_sunday', ' is_weekend', ' LDA_00', ' LDA_01', ' LDA_02',
#        ' LDA_03', ' LDA_04', ' global_subjectivity',
#        ' global_sentiment_polarity', ' global_rate_positive_words',
#        ' global_rate_negative_words', ' rate_positive_words',
#        ' rate_negative_words', ' avg_positive_polarity',
#        ' min_positive_polarity', ' max_positive_polarity',
#        ' avg_negative_polarity', ' min_negative_polarity',
#        ' max_negative_polarity', ' title_subjectivity',
#        ' title_sentiment_polarity', ' abs_title_subjectivity',
#        ' abs_title_sentiment_polarity', ' shares'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39644 entries, 0 to 39643
# Data columns (total 61 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   url                             39644 non-null  object
#  1    timedelta                      39644 non-null  float64
#  2    n_tokens_title                 39644 non-null  float64
#  3    n_tokens_content               39644 non-null  float64
#  4    n_unique_tokens                39644 non-null  float64
#  5    n_non_stop_words               39644 non-null  float64
#  6    n_non_stop_unique_tokens       39644 non-null  float64
#  7    num_hrefs                      39644 non-null  float64
#  8    num_self_hrefs                 39644 non-null  float64
#  9    num_imgs                       39644 non-null  float64
#  10   num_videos                     39644 non-null  float64
#  11   average_token_length           39644 non-null  float64
#  12   num_keywords                   39644 non-null  float64
#  13   data_channel_is_lifestyle      39644 non-null  float64
#  14   data_channel_is_entertainment  39644 non-null  float64
#  15   data_channel_is_bus            39644 non-null  float64
#  16   data_channel_is_socmed         39644 non-null  float64
#  17   data_channel_is_tech           39644 non-null  float64
#  18   data_channel_is_world          39644 non-null  float64
#  19   kw_min_min                     39644 non-null  float64
#  20   kw_max_min                     39644 non-null  float64
#  21   kw_avg_min                     39644 non-null  float64
#  22   kw_min_max                     39644 non-null  float64
#  23   kw_max_max                     39644 non-null  float64
#  24   kw_avg_max                     39644 non-null  float64
#  25   kw_min_avg                     39644 non-null  float64
#  26   kw_max_avg                     39644 non-null  float64
#  27   kw_avg_avg                     39644 non-null  float64
#  28   self_reference_min_shares      39644 non-null  float64
#  29   self_reference_max_shares      39644 non-null  float64
#  30   self_reference_avg_sharess     39644 non-null  float64
#  31   weekday_is_monday              39644 non-null  float64
#  32   weekday_is_tuesday             39644 non-null  float64
#  33   weekday_is_wednesday           39644 non-null  float64
#  34   weekday_is_thursday            39644 non-null  float64
#  35   weekday_is_friday              39644 non-null  float64
#  36   weekday_is_saturday            39644 non-null  float64
#  37   weekday_is_sunday              39644 non-null  float64
#  38   is_weekend                     39644 non-null  float64
#  39   LDA_00                         39644 non-null  float64
#  40   LDA_01                         39644 non-null  float64
#  41   LDA_02                         39644 non-null  float64
#  42   LDA_03                         39644 non-null  float64
#  43   LDA_04                         39644 non-null  float64
#  44   global_subjectivity            39644 non-null  float64
#  45   global_sentiment_polarity      39644 non-null  float64
#  46   global_rate_positive_words     39644 non-null  float64
#  47   global_rate_negative_words     39644 non-null  float64
#  48   rate_positive_words            39644 non-null  float64
#  49   rate_negative_words            39644 non-null  float64
#  50   avg_positive_polarity          39644 non-null  float64
#  51   min_positive_polarity          39644 non-null  float64
#  52   max_positive_polarity          39644 non-null  float64
#  53   avg_negative_polarity          39644 non-null  float64
#  54   min_negative_polarity          39644 non-null  float64
#  55   max_negative_polarity          39644 non-null  float64
#  56   title_subjectivity             39644 non-null  float64
#  57   title_sentiment_polarity       39644 non-null  float64
#  58   abs_title_subjectivity         39644 non-null  float64
#  59   abs_title_sentiment_polarity   39644 non-null  float64
#  60   shares                         39644 non-null  int64
# dtypes: float64(59), int64(1), object(1)
# memory usage: 18.5+ MB

# %%
df = df.drop('url', axis=1)

# %%
x = df.drop(' shares', axis=1)
y = df[' shares']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.2, random_state=42)

# %%
x_train.shape
# Out:
# (31715, 59)

# %%
x_test.shape
# Out:
# (7929, 59)

# %%
y_train.shape
# Out:
# (31715,)

# %%
y_test.shape
# Out:
# (7929,)

# %%
import numpy as np

# %%
y_train =  np.log1p(y_train)
y_test = np.log1p(y_test)

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
# %pip install --upgrade joblib scikit-learn pandas

import tensorflow as tf
from tensorflow.keras import layers, models
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 3
#       1 get_ipython().run_line_magic('pip', 'install --upgrade joblib scikit-learn pandas')
# ----> 3 import tensorflow as tf
#       4 from tensorflow.keras import layers, models
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:13
#      11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
# ---> 13 from tensorflow._api.v2.__internal__ import feature_column
#      14 from tensorflow._api.v2.__internal__ import function
#      15 from tensorflow._api.v2.__internal__ import graph_util
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\feature_column\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.feature_column namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn # line: 1777
#       9 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCache # line: 1962
#      10 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn # line: 1941
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:38
#      36 from tensorflow.python.data.ops import readers
#      37 from tensorflow.python.eager import context
# ---> 38 from tensorflow.python.feature_column import feature_column as fc_old
#      39 from tensorflow.python.feature_column import feature_column_v2_types as fc_types
#      40 from tensorflow.python.feature_column import serialization
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\feature_column\feature_column.py:41
#      39 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#      40 from tensorflow.python.framework import tensor_shape
# ---> 41 from tensorflow.python.layers import base
#      42 from tensorflow.python.ops import array_ops
#      43 from tensorflow.python.ops import array_ops_stack
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\layers\base.py:16
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      18 InputSpec = base.InputSpec
#      20 keras_style_scope = base.keras_style_scope
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\__init__.py:25
#      22 from tensorflow.python.keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      27 from tensorflow.python.keras.engine.input_layer import Input
#      28 from tensorflow.python.keras.engine.sequential import Sequential
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\models.py:22
#      20 from tensorflow.python.keras import metrics as metrics_module
#      21 from tensorflow.python.keras import optimizer_v1
# ---> 22 from tensorflow.python.keras.engine import functional
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\engine\functional.py:33
#      31 from tensorflow.python.keras.engine import input_spec
#      32 from tensorflow.python.keras.engine import node as node_module
# ---> 33 from tensorflow.python.keras.engine import training as training_lib
#      34 from tensorflow.python.keras.engine import training_utils
#      35 from tensorflow.python.keras.saving.saved_model import network_serialization
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\engine\training.py:54
#      52 from tensorflow.python.keras.mixed_precision import loss_scale_optimizer as lso
#      53 from tensorflow.python.keras.mixed_precision import policy
# ---> 54 from tensorflow.python.keras.saving import hdf5_format
#      55 from tensorflow.python.keras.saving import save
#      56 from tensorflow.python.keras.saving import saving_utils
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py:37
#      35 # pylint: disable=g-import-not-at-top
#      36 try:
# ---> 37   import h5py
#      38   HDF5_OBJECT_HEADER_LIMIT = 64512
#      39 except ImportError:
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\h5py\__init__.py:56
#      51 _register_lzf()
#      54 # --- Public API --------------------------------------------------------------
# ---> 56 from . import h5a, h5d, h5ds, h5f, h5fd, h5g, h5r, h5s, h5t, h5p, h5z, h5pl
#      58 from ._hl import filters
#      59 from ._hl.base import is_hdf5, HLObject, Empty
#
# File h5py/h5f.pyx:1, in init h5py.h5f()
#
# KeyError: '__reduce_cython__'
# Requirement already satisfied: joblib in d:\shaher\amit\.venv\lib\site-packages (1.5.2)
# Requirement already satisfied: scikit-learn in d:\shaher\amit\.venv\lib\site-packages (1.7.2)
# Requirement already satisfied: pandas in d:\shaher\amit\.venv\lib\site-packages (2.3.0)
# Collecting pandas
#   Using cached pandas-2.3.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.0 in d:\shaher\amit\.venv\lib\site-packages (from scikit-learn) (2.3.1)
# Requirement already satisfied: scipy>=1.8.0 in d:\shaher\amit\.venv\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\shaher\amit\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\shaher\amit\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\shaher\amit\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\shaher\amit\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in d:\shaher\amit\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.2-cp312-cp312-win_amd64.whl (11.0 MB)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.3.0
#     Uninstalling pandas-2.3.0:
#       Successfully uninstalled pandas-2.3.0
#   Rolling back uninstall of pandas
#   Moving to d:\shaher\amit\.venv\lib\site-packages\pandas-2.3.0.dist-info\
#    from D:\Shaher\AMIT\.venv\Lib\site-packages\~andas-2.3.0.dist-info
#   Moving to d:\shaher\amit\.venv\lib\site-packages\pandas.libs\
#    from D:\Shaher\AMIT\.venv\Lib\site-packages\~andas.libs
#   Moving to d:\shaher\amit\.venv\lib\site-packages\pandas\
#    from D:\Shaher\AMIT\.venv\Lib\site-packages\~andas
# WARNING: Ignoring invalid distribution ~cikit-learn (d:\Shaher\AMIT\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~cikit-learn (d:\Shaher\AMIT\.venv\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: 'd:\\Shaher\\AMIT\\.venv\\Lib\\site-packages\\pandas-2.3.2.dist-info\\INSTALLERak_z5mxt.tmp'

# %%
model = models.Sequential([
    layers.Dense(256, activation='relu', input_shape=(x_train.shape[1],)),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),

    layers.Dense(64, activation='relu'),

    layers.Dense(1, activation='linear') #output
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
early_Stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=13-6)

# %%
from sklearn.metrics import r2_score

# %%
from tensorflow.keras import backend as k

# %%
def r2_score_custom(y_true, y_pred):
  y_true = k.cast(y_true, 'float32')
  ss_res = k.sum(k.square(y_true - y_pred))
  ss_tot = k.sum(k.square(y_true - k.mean(y_true)))
  return (1 - ss_res/(ss_tot + k.epsilon()))

# %%
model.compile(optimizer='adam', loss='mse', metrics=['mae', r2_score_custom])

# %%
history = model.fit(x_train, y_train,
                    epochs=100, batch_size=128,
                    validation_data=(x_test, y_test),
                    callbacks=[early_Stop, reduce_lr])
# Out:
# Epoch 1/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 12.6225 - mae: 2.5551 - r2_score_custom: -14.3856 - val_loss: 2.1441 - val_mae: 0.8983 - val_r2_score_custom: -1.4442 - learning_rate: 0.0010
# Epoch 2/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.4386 - mae: 0.9251 - r2_score_custom: -0.7039 - val_loss: 1.2926 - val_mae: 0.7117 - val_r2_score_custom: -0.4818 - learning_rate: 0.0010
# Epoch 3/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 1.2976 - mae: 0.8738 - r2_score_custom: -0.5340 - val_loss: 1.3696 - val_mae: 0.7025 - val_r2_score_custom: -0.5848 - learning_rate: 0.0010
# Epoch 4/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2535 - mae: 0.8612 - r2_score_custom: -0.4671 - val_loss: 0.9360 - val_mae: 0.7364 - val_r2_score_custom: -0.1012 - learning_rate: 0.0010
# Epoch 5/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.2152 - mae: 0.8456 - r2_score_custom: -0.4193 - val_loss: 0.9224 - val_mae: 0.7058 - val_r2_score_custom: -0.0830 - learning_rate: 0.0010
# Epoch 6/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.1855 - mae: 0.8332 - r2_score_custom: -0.3736 - val_loss: 0.9552 - val_mae: 0.6986 - val_r2_score_custom: -0.1153 - learning_rate: 0.0010
# Epoch 7/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 1.1738 - mae: 0.8275 - r2_score_custom: -0.3604 - val_loss: 0.9503 - val_mae: 0.6797 - val_r2_score_custom: -0.1075 - learning_rate: 0.0010
# Epoch 8/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.1245 - mae: 0.8052 - r2_score_custom: -0.3315 - val_loss: 0.8889 - val_mae: 0.6843 - val_r2_score_custom: -0.0370 - learning_rate: 0.0010
# Epoch 9/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.1095 - mae: 0.8046 - r2_score_custom: -0.3124 - val_loss: 0.8838 - val_mae: 0.7073 - val_r2_score_custom: -0.0371 - learning_rate: 0.0010
# Epoch 10/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.0771 - mae: 0.7954 - r2_score_custom: -0.2655 - val_loss: 0.8846 - val_mae: 0.6820 - val_r2_score_custom: -0.0372 - learning_rate: 0.0010
# Epoch 11/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 1.0629 - mae: 0.7857 - r2_score_custom: -0.2857 - val_loss: 0.9381 - val_mae: 0.6718 - val_r2_score_custom: -0.0896 - learning_rate: 0.0010
# Epoch 12/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.0477 - mae: 0.7794 - r2_score_custom: -0.2298 - val_loss: 0.9870 - val_mae: 0.6887 - val_r2_score_custom: -0.1521 - learning_rate: 0.0010
# Epoch 13/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.0145 - mae: 0.7667 - r2_score_custom: -0.1936 - val_loss: 0.9964 - val_mae: 0.7082 - val_r2_score_custom: -0.1637 - learning_rate: 0.0010
# Epoch 14/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 1.0103 - mae: 0.7610 - r2_score_custom: -0.1831 - val_loss: 1.0410 - val_mae: 0.6900 - val_r2_score_custom: -0.2026 - learning_rate: 0.0010
# Epoch 15/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.9830 - mae: 0.7504 - r2_score_custom: -0.1516 - val_loss: 1.0759 - val_mae: 0.7061 - val_r2_score_custom: -0.2518 - learning_rate: 0.0010
# Epoch 16/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.9806 - mae: 0.7473 - r2_score_custom: -0.1312 - val_loss: 1.3730 - val_mae: 0.6828 - val_r2_score_custom: -0.6300 - learning_rate: 0.0010
# Epoch 17/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.9518 - mae: 0.7415 - r2_score_custom: -0.1058 - val_loss: 4.4305 - val_mae: 0.7013 - val_r2_score_custom: -4.6390 - learning_rate: 0.0010
# Epoch 18/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.9465 - mae: 0.7314 - r2_score_custom: -0.0996 - val_loss: 6.0368 - val_mae: 0.7676 - val_r2_score_custom: -6.7160 - learning_rate: 0.0010
# Epoch 19/100
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 0.9217 - mae: 0.7273 - r2_score_custom: -0.0836 - val_loss: 6.1986 - val_mae: 0.7095 - val_r2_score_custom: -6.9912 - learning_rate: 0.0010

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['mae'], label='Train MAE')
plt.plot(history.history['val_mae'], label='Val MAE')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.title('Training vs Validation MAE')
plt.show()

# %%
y_pred = model.predict(x_test)
# Out:
# 248/248 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
r2_score(y_test, y_pred)
# Out:
# -0.031005361607343573

# %%
# y_pred = model.predict(x_test).flatten()

# %%
# r2_score(np.expm1(y_test), np.expm1(y_pred))

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.7073007381901657

# %%
# mean_absolute_error(np.expm1(y_test), np.expm1(y_pred))

# %% [markdown]
# # **Denoising Autoencoder (DAE)**

# %% [markdown]
# ## 📝 Task: Build a Simple Autoencoder for Noisy Data
#
# ## Objective
# The dataset you are working with already contains a lot of **noise**.
# Your task is to build a **simple Autoencoder** that learns a cleaner representation of the features and produces latent features for downstream tasks.
#
# ---
#
# ## Steps
#
# ### 1️⃣ Prepare Data
# - Use `X_train` and `X_test` directly.
# - Ensure the input shape matches the number of features.
#
# 💡 *Hint: you can check it with `X_train.shape[1]`.*
#
# ---
#
# ### 2️⃣ Build Autoencoder
# - Input layer = number of features.
# - Encoder: one hidden dense layer (e.g., 64 units, ReLU).
# - Decoder: one dense layer that reconstructs the input (linear activation).
#
# 💡 *Hint: Encoder reduces the dimensionality, Decoder reconstructs the original features.*
#
# ---
#
# ### 3️⃣ Train Autoencoder
# - Train the model to reconstruct the inputs.
# - Use `"mse"` loss and `"adam"` optimizer.
# - Train for ~20 epochs, batch size 128.
# - Validate on `(X_test, X_test)`.
#
# 💡 *Hint: the target is the same as the input (`X_train → X_train`).*
#
# ---
#
# ### 4️⃣ Extract Encoder
# - Define a new model that outputs the **encoded layer** only.
# - Transform `X_train` and `X_test` into latent features (`Z_train`, `Z_test`).
#
# 💡 *Hint: `encoder = Model(inputs, encoded_layer)`.*
#
# ---
#
# ## Deliverables
# - Training and validation loss curve (plot).
# - Latent features: print shape of `Z_train` and `Z_test`.
# - Short reflection: *Do latent features seem more compact/cleaner than raw inputs?*

# %%
# Example: Using an Autoencoder for Dimensionality Reduction and Anomaly Detection
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler

# Assume X_train is your training data (features only, no labels)
# 1. Scale the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# 2. Build the autoencoder
input_dim = X_train_scaled.shape[1]
encoding_dim = 8  # You can tune this value

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
decoded = Dense(input_dim, activation='linear')(encoded)

autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer=Adam(learning_rate=0.001), loss='mse')

# 3. Train the autoencoder
history = autoencoder.fit(
    X_train_scaled, X_train_scaled,
    epochs=50,
    batch_size=32,
    shuffle=True,
    validation_data=(X_test_scaled, X_test_scaled),
    verbose=1
)

# 4. Get the encoded (compressed) features
encoder = Model(inputs=input_layer, outputs=encoded)
X_train_encoded = encoder.predict(X_train_scaled)
X_test_encoded = encoder.predict(X_test_scaled)

# 5. (Optional) Use the encoded features for downstream tasks (e.g., classification)
# Example: Train a classifier on X_train_encoded, y_train

# 6. (Optional) Anomaly detection: Calculate reconstruction error
reconstructions = autoencoder.predict(X_test_scaled)
mse = np.mean(np.square(X_test_scaled - reconstructions), axis=1)

# You can set a threshold for anomaly detection based on mse
threshold = np.percentile(mse, 95)
anomalies = mse > threshold

print(f"Number of anomalies detected: {np.sum(anomalies)}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Example: Using an Autoencoder for Dimensionality Reduction and Anomaly Detection
# ----> 2 from tensorflow.keras.models import Model
#       3 from tensorflow.keras.layers import Input, Dense
#       4 from tensorflow.keras.optimizers import Adam
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\__init__.py:49
#      46 from tensorflow.python import tf2 as _tf2
#      47 _tf2.enable()
# ---> 49 from tensorflow._api.v2 import __internal__
#      50 from tensorflow._api.v2 import __operators__
#      51 from tensorflow._api.v2 import audio
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:13
#      11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
# ---> 13 from tensorflow._api.v2.__internal__ import feature_column
#      14 from tensorflow._api.v2.__internal__ import function
#      15 from tensorflow._api.v2.__internal__ import graph_util
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\_api\v2\__internal__\feature_column\__init__.py:8
#       3 """Public API for tf._api.v2.__internal__.feature_column namespace
#       4 """
#       6 import sys as _sys
# ----> 8 from tensorflow.python.feature_column.feature_column_v2 import DenseColumn # line: 1777
#       9 from tensorflow.python.feature_column.feature_column_v2 import FeatureTransformationCache # line: 1962
#      10 from tensorflow.python.feature_column.feature_column_v2 import SequenceDenseColumn # line: 1941
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\feature_column\feature_column_v2.py:38
#      36 from tensorflow.python.data.ops import readers
#      37 from tensorflow.python.eager import context
# ---> 38 from tensorflow.python.feature_column import feature_column as fc_old
#      39 from tensorflow.python.feature_column import feature_column_v2_types as fc_types
#      40 from tensorflow.python.feature_column import serialization
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\feature_column\feature_column.py:41
#      39 from tensorflow.python.framework import sparse_tensor as sparse_tensor_lib
#      40 from tensorflow.python.framework import tensor_shape
# ---> 41 from tensorflow.python.layers import base
#      42 from tensorflow.python.ops import array_ops
#      43 from tensorflow.python.ops import array_ops_stack
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\layers\base.py:16
#       1 # Copyright 2015 The TensorFlow Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)     13 # limitations under the License.
#      14 # =============================================================================
#      15 """Contains the base Layer class, from which all layers inherit."""
# ---> 16 from tensorflow.python.keras.legacy_tf_layers import base
#      18 InputSpec = base.InputSpec
#      20 keras_style_scope = base.keras_style_scope
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\__init__.py:25
#      22 from tensorflow.python.keras import distribute
#      24 # See b/110718070#comment18 for more details about this import.
# ---> 25 from tensorflow.python.keras import models
#      27 from tensorflow.python.keras.engine.input_layer import Input
#      28 from tensorflow.python.keras.engine.sequential import Sequential
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\models.py:22
#      20 from tensorflow.python.keras import metrics as metrics_module
#      21 from tensorflow.python.keras import optimizer_v1
# ---> 22 from tensorflow.python.keras.engine import functional
#      23 from tensorflow.python.keras.engine import sequential
#      24 from tensorflow.python.keras.engine import training
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\engine\functional.py:33
#      31 from tensorflow.python.keras.engine import input_spec
#      32 from tensorflow.python.keras.engine import node as node_module
# ---> 33 from tensorflow.python.keras.engine import training as training_lib
#      34 from tensorflow.python.keras.engine import training_utils
#      35 from tensorflow.python.keras.saving.saved_model import network_serialization
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\engine\training.py:54
#      52 from tensorflow.python.keras.mixed_precision import loss_scale_optimizer as lso
#      53 from tensorflow.python.keras.mixed_precision import policy
# ---> 54 from tensorflow.python.keras.saving import hdf5_format
#      55 from tensorflow.python.keras.saving import save
#      56 from tensorflow.python.keras.saving import saving_utils
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py:37
#      35 # pylint: disable=g-import-not-at-top
#      36 try:
# ---> 37   import h5py
#      38   HDF5_OBJECT_HEADER_LIMIT = 64512
#      39 except ImportError:
#
# File d:\Shaher\AMIT\.venv\Lib\site-packages\h5py\__init__.py:56
#      51 _register_lzf()
#      54 # --- Public API --------------------------------------------------------------
# ---> 56 from . import h5a, h5d, h5ds, h5f, h5fd, h5g, h5r, h5s, h5t, h5p, h5z, h5pl
#      58 from ._hl import filters
#      59 from ._hl.base import is_hdf5, HLObject, Empty
#
# File h5py/h5f.pyx:29, in init h5py.h5f()
#
# File <frozen importlib._bootstrap>:645, in parent(self)
#
# KeyboardInterrupt:
